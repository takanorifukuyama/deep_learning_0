# %% [markdown]
# ## 数値計算が専門でない理系向けのJulia入門
#
# こちらを参考にしています
# https://github.com/akio-tomiya/intro_julia_minimum/blob/main/short_intro_julia.ipynb

# %%
import PyPlot; plt
# Out:
# ArgumentError: Package PyPlot not found in current path:
# - Run `import Pkg; Pkg.add("PyPlot")` to install the PyPlot package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:893
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
import Pkg; Pkg.add("PyPlot")
# Out:
#    Updating registry at `~/.julia/registries/General`
#   Resolving package versions...
#   Installed LaTeXStrings ────── v1.2.0
#   Installed PyPlot ──────────── v2.9.0
#   Installed FixedPointNumbers ─ v0.8.4
#   Installed ColorTypes ──────── v0.10.9
#   Installed MacroTools ──────── v0.5.6
#   Installed PyCall ──────────── v1.92.1
#   Installed Colors ──────────── v0.12.4
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [d330b81b] + PyPlot v2.9.0
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [3da002f7] + ColorTypes v0.10.9
#   [5ae59095] + Colors v0.12.4
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [b964fa9f] + LaTeXStrings v1.2.0
#   [1914dd2f] + MacroTools v0.5.6
#   [438e738f] + PyCall v1.92.1
#   [d330b81b] + PyPlot v2.9.0
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#    Building PyCall → `~/.julia/packages/PyCall/BcTLp/deps/build.log`
# ┌ Error: Error building `PyCall`, showing the last 100 of log:
# ...

# %%
import PyPlot; plt
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1278
# ERROR: LoadError: LoadError: PyCall not properly installed. Please run Pkg.build("PyCall")
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] top-level scope at /Users/takanorifukuyama/.julia/packages/PyCall/BcTLp/src/startup.jl:44
#  [3] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [4] include at ./Base.jl:368 [inlined]
#  [5] include(::String) at /Users/takanorifukuyama/.julia/packages/PyCall/BcTLp/src/PyCall.jl:1
#  [6] top-level scope at /Users/takanorifukuyama/.julia/packages/PyCall/BcTLp/src/PyCall.jl:38
#  [7] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [8] include(::Module, ::String) at ./Base.jl:368
#  [9] top-level scope at none:2
#  [10] eval at ./boot.jl:331 [inlined]
#  [11] eval(::Expr) at ./client.jl:467
#  [12] top-level scope at ./none:3
# ...

# %%
Pkg.build("PyCall")
# Out:
#    Building Conda ─→ `~/.julia/packages/Conda/x5ml4/deps/build.log`
#    Building PyCall → `~/.julia/packages/PyCall/BcTLp/deps/build.log`

# %%
import Pkg; Pkg.add("PyPlot")
# Out:
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
import PyPlot: plt

# %%
x=collect(0:0.1:2π)
y=sin.(x)
plt.plot(x, y)
plt.xlabel(raw"$x$")
plt.ylabel(raw"$\sin(x)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
x=collect(0:0.1:2π) # 0から2πまで0.1刻みの変数を用意する。
y=sin.(x) # sinをxの各要素に作用させる。
plt.plot(x,y)
plt.xlabel(raw"$x$")
plt.ylabel(raw"$\sin(x)$") #LaTeX 記法を使うため、raw をつける。
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
collect(0:0.1:2π)
# Out:
# 63-element Array{Float64,1}:
#  0.0
#  0.1
#  0.2
#  0.30000000000000004
#  0.4
#  0.5
#  0.6000000000000001
#  0.7000000000000001
#  0.8
#  0.9
#  1.0
#  1.1
#  1.2000000000000002
#  ⋮
#  5.1000000000000005
#  5.2
#  5.300000000000001
#  5.4
#  5.5
#  5.6000000000000005
#  5.7
#  5.800000000000001
#  5.9
#  6.0
#  6.1000000000000005
#  6.2

# %%
Ndata = 10
x=range(0, 1, length=Ndata)
y=2*x
e=rand(Float64, Ndata)/10

plt.errorbar(x, y, yerr=e)
plt.xlabel("x")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
x=randn(10000)
plt.hist(x, bins=100)
plt.xlabel("x")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ここで`rand()`は世紀分部に従う乱数を生成する関数

# %% [markdown]
# ## Numpyを使う

# %%
import Pkg; Pkg.add("PyCall")
# Out:
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [438e738f] + PyCall v1.92.1
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
using PyCall
np=pyimport("numpy");

# %%
np.linspace(0, 1, 5)
# Out:
# 5-element Array{Float64,1}:
#  0.0
#  0.25
#  0.5
#  0.75
#  1.0
